# %% [markdown]
# # Biblioteca Numoy

# %% [markdown]
# 3 librerías:
#
# - **Numpy**: biblioteca que nos permite manejar **arrays* python de serie no tiene
# - **Pandas**: biblioteca para manejar **series** y **dataframes** (tablas)
# - **Matplotlib**: permite visualizar gráficos
#
# Son externas a python, se instalan:

# %% [markdown]
# Instalación:
# ! es para que puedas coger el cmd y ejecutar la instalación.

# %%
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.9 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 649.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/16.2 MB 3.6 MB/s eta 0:00:05
#     --------------------------------------- 0.4/16.2 MB 3.9 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/16.2 MB 4.5 MB/s eta 0:00:04
#    -- ------------------------------------- 1.0/16.2 MB 5.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/16.2 MB 6.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.1/16.2 MB 7.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.6/16.2 MB 7.8 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/16.2 MB 8.2 MB/s eta 0:00:02
# ...

# %%
# !pip install --upgrade pip # si queremos upgradear el pip
# en el cmd:  python -m pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.8 MB 1.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.8 MB 2.5 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/1.8 MB 2.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/1.8 MB 2.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.8 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.5/1.8 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.8 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.8 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# C:\Users\Alumne_tarda1\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# ...
